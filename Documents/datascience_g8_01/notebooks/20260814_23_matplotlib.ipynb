# %%
import matplotlib

print(matplotlib.__version__)
# Out:
# 3.11.1

# %%
import numpy as np

x = np.linspace(0,5,10)
y = x ** 2

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x,y)
plt.show()

# %%
plt.plot(x,y, "g")
plt.show()

# %%
plt.plot(x,y, "r")
plt.show()

# %%
plt.plot(x,y,"ro")

# %%
plt.plot(x,y,"ro-")

# %%
plt.plot(x,y,"gD:")
