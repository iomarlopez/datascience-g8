# %%
import pandas as pd
ventas= pd.read_csv(
    "../data/ventas.csv",
    dtype={"precio_unitario": "float64"}
)

# %%
ventas.head(10)
# Out:
#         fecha  region     vendedor     producto   categoria  unidades  \
# 0  2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 1  2024-01-02     Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 2  2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 3  2024-01-02  Centro   Pedro Diaz   Laptop Pro  Tecnologia        10
# 4  2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 5  2024-01-03   Oeste  Javier Sanz   Escritorio  Mobiliario         2
# 6  2024-01-03   Norte  Carlos Vega   Silla Ergo  Mobiliario         4
# 7  2024-01-03   Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 8  2024-01-03  Centro  Carlos Vega   Laptop Pro  Tecnologia         1
# 9  2024-01-03  Centro   Pedro Diaz   Escritorio  Mobiliario         2
#
#    precio_unitario  descuento
# 0              130        0.0
# 1              320        0.0
# 2              280        0.0
# 3             1200        0.0
# 4              130        0.1
# ...

# %%
mascara = ventas["region"] =="Sur"
ventas_sur = ventas[mascara]
ventas_sur.tail()
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1156  2024-12-17    Sur   Luis Gomez  Teclado Mec  Accesorios        11
# 1163  2024-12-19    Sur   Luis Gomez   Silla Ergo  Mobiliario         2
# 1181  2024-12-25    Sur   Ana Torres   Tablet Air  Tecnologia        14
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
#
#       precio_unitario  descuento
# 1156               95       0.15
# 1163              280       0.00
# 1181              640       0.00
# 1191              280       0.00
# 1192               95       0.10

# %%
ventas[ventas["region"] == "Sur"]
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1     2024-01-02    Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 4     2024-01-03    Sur   Elena Mora  Auriculares  Accesorios         2
# 14    2024-01-05    Sur   Pedro Diaz  Teclado Mec  Accesorios        12
# 21    2024-01-07    Sur   Marta Ruiz  Auriculares  Accesorios         4
# 22    2024-01-08    Sur   Elena Mora  Teclado Mec  Accesorios         3
# ...          ...    ...          ...          ...         ...       ...
# 1156  2024-12-17    Sur   Luis Gomez  Teclado Mec  Accesorios        11
# 1163  2024-12-19    Sur   Luis Gomez   Silla Ergo  Mobiliario         2
# 1181  2024-12-25    Sur   Ana Torres   Tablet Air  Tecnologia        14
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
#
#       precio_unitario  descuento
# 1                 320       0.00
# 4                 130       0.10
# ...

# %%
df_filtrado=ventas[ (ventas["region"] == "Sur") & (ventas["precio_unitario"] > 90) ]
df_filtrado
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1     2024-01-02    Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 4     2024-01-03    Sur   Elena Mora  Auriculares  Accesorios         2
# 14    2024-01-05    Sur   Pedro Diaz  Teclado Mec  Accesorios        12
# 21    2024-01-07    Sur   Marta Ruiz  Auriculares  Accesorios         4
# 22    2024-01-08    Sur   Elena Mora  Teclado Mec  Accesorios         3
# ...          ...    ...          ...          ...         ...       ...
# 1156  2024-12-17    Sur   Luis Gomez  Teclado Mec  Accesorios        11
# 1163  2024-12-19    Sur   Luis Gomez   Silla Ergo  Mobiliario         2
# 1181  2024-12-25    Sur   Ana Torres   Tablet Air  Tecnologia        14
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
#
#       precio_unitario  descuento
# 1                 320       0.00
# 4                 130       0.10
# ...

# %%
df_filtrado = ventas[ (ventas["region"] == "Sur") | (ventas["region"] == "Norte")]
df_filtrado
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1     2024-01-02    Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 4     2024-01-03    Sur   Elena Mora  Auriculares  Accesorios         2
# 6     2024-01-03  Norte  Carlos Vega   Silla Ergo  Mobiliario         4
# 7     2024-01-03  Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 10    2024-01-04  Norte   Sofia Leon   Monitor 27  Tecnologia         3
# ...          ...    ...          ...          ...         ...       ...
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
# 1194  2024-12-30  Norte   Ana Torres   Tablet Air  Tecnologia         4
# 1198  2024-12-31  Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31  Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 1                 320        0.0
# 4                 130        0.1
# ...

# %%
ventas [ ventas["unidades"] == 1]
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 2     2024-01-02  Centro  Carlos Vega   Silla Ergo  Mobiliario         1
# 7     2024-01-03   Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 8     2024-01-03  Centro  Carlos Vega   Laptop Pro  Tecnologia         1
# 17    2024-01-06   Oeste   Marta Ruiz   Laptop Pro  Tecnologia         1
# 26    2024-01-09  Centro   Sofia Leon  Teclado Mec  Accesorios         1
# ...          ...     ...          ...          ...         ...       ...
# 1126  2024-12-08     Sur   Pedro Diaz   Escritorio  Mobiliario         1
# 1137  2024-12-12   Norte   Pedro Diaz  Teclado Mec  Accesorios         1
# 1146  2024-12-15   Norte   Pedro Diaz   Laptop Pro  Tecnologia         1
# 1164  2024-12-20   Norte  Javier Sanz   Escritorio  Mobiliario         1
# 1190  2024-12-29  Centro   Luis Gomez   Laptop Pro  Tecnologia         1
#
#       precio_unitario  descuento
# 2                 280       0.00
# ...

# %%
df_filtrado["region"].unique()
# Out:
# <StringArray>
# ['Sur', 'Norte']
# Length: 2, dtype: str

# %%
sorted(df_filtrado["precio_unitario"].unique())
# Out:
# [np.int64(95),
#  np.int64(130),
#  np.int64(280),
#  np.int64(320),
#  np.int64(450),
#  np.int64(640),
#  np.int64(1200)]

# %%
ventas[ ventas["region"].isin(["Sur", "Norte"])]
# Out:
#            fecha region     vendedor     producto   categoria  unidades  \
# 1     2024-01-02    Sur   Luis Gomez   Monitor 27  Tecnologia        14
# 4     2024-01-03    Sur   Elena Mora  Auriculares  Accesorios         2
# 6     2024-01-03  Norte  Carlos Vega   Silla Ergo  Mobiliario         4
# 7     2024-01-03  Norte   Sofia Leon   Silla Ergo  Mobiliario         1
# 10    2024-01-04  Norte   Sofia Leon   Monitor 27  Tecnologia         3
# ...          ...    ...          ...          ...         ...       ...
# 1191  2024-12-30    Sur   Luis Gomez   Silla Ergo  Mobiliario         3
# 1192  2024-12-30    Sur  Javier Sanz  Teclado Mec  Accesorios         8
# 1194  2024-12-30  Norte   Ana Torres   Tablet Air  Tecnologia         4
# 1198  2024-12-31  Norte   Ana Torres   Monitor 27  Tecnologia         6
# 1199  2024-12-31  Norte   Marta Ruiz   Raton Ergo  Accesorios         8
#
#       precio_unitario  descuento
# 1               320.0        0.0
# 4               130.0        0.1
# ...

# %%
df_filtrado = ventas[ventas["precio_unitario"].between(90,200)]
df_filtrado
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 0     2024-01-02   Oeste   Pedro Diaz  Auriculares  Accesorios         5
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 13    2024-01-05   Norte   Sofia Leon  Auriculares  Accesorios        11
# 14    2024-01-05     Sur   Pedro Diaz  Teclado Mec  Accesorios        12
# 18    2024-01-06   Oeste  Carlos Vega  Auriculares  Accesorios         2
# ...          ...     ...          ...          ...         ...       ...
# 1173  2024-12-22   Norte   Marta Ruiz  Teclado Mec  Accesorios        12
# 1177  2024-12-24   Oeste   Ana Torres  Auriculares  Accesorios        11
# 1183  2024-12-26  Centro   Luis Gomez  Auriculares  Accesorios         6
# 1189  2024-12-29   Oeste  Javier Sanz  Auriculares  Accesorios         6
# 1192  2024-12-30     Sur  Javier Sanz  Teclado Mec  Accesorios         8
#
#       precio_unitario  descuento
# 0               130.0       0.00
# ...

# %%
df_filtrado["precio_unitario"]
# Out:
# 0       130.0
# 4       130.0
# 13      130.0
# 14       95.0
# 18      130.0
#         ...
# 1173     95.0
# 1177    130.0
# 1183    130.0
# 1189    130.0
# 1192     95.0
# Name: precio_unitario, Length: 291, dtype: float64

# %%
# ¿Cuántas operaciones se hicieron en la region Centro?

##ventas["region"].value_counts()["Centro"]
##(ventas["region"] == "Centro").sum()
len(ventas[ventas["region"] == "Centro"])
# Out:
# 272

# %%
# Muestra las ventas de Tecnología con mas de 10 unidades

ventas[(ventas["categoria"] == "Tecnologia") & (ventas["unidades"] >10)]
# Out:
#            fecha  region     vendedor    producto   categoria  unidades  \
# 1     2024-01-02     Sur   Luis Gomez  Monitor 27  Tecnologia        14
# 16    2024-01-06  Centro   Ana Torres  Laptop Pro  Tecnologia        13
# 27    2024-01-09    Este  Carlos Vega  Laptop Pro  Tecnologia        12
# 40    2024-01-14  Centro   Marta Ruiz  Laptop Pro  Tecnologia        12
# 89    2024-01-31  Centro   Sofia Leon  Monitor 27  Tecnologia        12
# ...          ...     ...          ...         ...         ...       ...
# 1174  2024-12-22   Norte          NaN  Laptop Pro  Tecnologia        14
# 1176  2024-12-23  Centro  Carlos Vega  Monitor 27  Tecnologia        11
# 1181  2024-12-25     Sur   Ana Torres  Tablet Air  Tecnologia        14
# 1188  2024-12-28    Este   Luis Gomez  Tablet Air  Tecnologia        13
# 1196  2024-12-30    Este   Marta Ruiz  Laptop Pro  Tecnologia        13
#
#       precio_unitario  descuento
# 1               320.0       0.00
# 16             1200.0       0.00
# ...

# %%
# ¿Que ventas tuvieron algun descuento (mayor que 0)?

ventas[ventas["descuento"] >0]
# Out:
#            fecha  region     vendedor     producto   categoria  unidades  \
# 4     2024-01-03     Sur   Elena Mora  Auriculares  Accesorios         2
# 8     2024-01-03  Centro  Carlos Vega   Laptop Pro  Tecnologia         1
# 10    2024-01-04   Norte   Sofia Leon   Monitor 27  Tecnologia         3
# 11    2024-01-04   Oeste   Pedro Diaz   Escritorio  Mobiliario        10
# 12    2024-01-04  Centro   Marta Ruiz   Tablet Air  Tecnologia         2
# ...          ...     ...          ...          ...         ...       ...
# 1187  2024-12-28    Este   Ana Torres   Raton Ergo  Accesorios         8
# 1190  2024-12-29  Centro   Luis Gomez   Laptop Pro  Tecnologia         1
# 1192  2024-12-30     Sur  Javier Sanz  Teclado Mec  Accesorios         8
# 1196  2024-12-30    Este   Marta Ruiz   Laptop Pro  Tecnologia        13
# 1197  2024-12-31   Oeste   Ana Torres   Monitor 27  Tecnologia         2
#
#       precio_unitario  descuento
# 4               130.0       0.10
# ...

# %%
## Ventas de las regiones Norte o Sur del producto "Latop PRO"

ventas[(ventas["region"].isin(["Norte", "Sur"])) & (ventas["producto"] == "Laptop Pro")]
# Out:
#            fecha region     vendedor    producto   categoria  unidades  \
# 33    2024-01-11    Sur  Javier Sanz  Laptop Pro  Tecnologia         5
# 108   2024-02-04    Sur   Ana Torres  Laptop Pro  Tecnologia         6
# 119   2024-02-08  Norte   Luis Gomez  Laptop Pro  Tecnologia         6
# 129   2024-02-11  Norte   Ana Torres  Laptop Pro  Tecnologia         2
# 139   2024-02-13    Sur   Elena Mora  Laptop Pro  Tecnologia         8
# ...          ...    ...          ...         ...         ...       ...
# 1100  2024-12-02    Sur   Sofia Leon  Laptop Pro  Tecnologia        10
# 1105  2024-12-03    Sur   Sofia Leon  Laptop Pro  Tecnologia         7
# 1123  2024-12-08  Norte  Javier Sanz  Laptop Pro  Tecnologia        13
# 1146  2024-12-15  Norte   Pedro Diaz  Laptop Pro  Tecnologia         1
# 1174  2024-12-22  Norte          NaN  Laptop Pro  Tecnologia        14
#
#       precio_unitario  descuento
# 33             1200.0        NaN
# 108            1200.0       0.00
# ...

# %%
# Ventas con importe superior a 5.000 ordenados de mayor a menos

ventas["importe"] = ventas["unidades"] * ventas["precio_unitario"]

ventas[ ventas["importe"] > 5000].sort_values("importe", ascending=False)
# Out:
#            fecha  region    vendedor    producto   categoria  unidades  \
# 340   2024-04-16    Este  Marta Ruiz  Laptop Pro  Tecnologia        14
# 344   2024-04-18   Norte  Luis Gomez  Laptop Pro  Tecnologia        14
# 1174  2024-12-22   Norte         NaN  Laptop Pro  Tecnologia        14
# 952   2024-10-17     Sur  Luis Gomez  Laptop Pro  Tecnologia        14
# 871   2024-09-25     Sur  Luis Gomez  Laptop Pro  Tecnologia        14
# ...          ...     ...         ...         ...         ...       ...
# 1065  2024-11-20    Este  Elena Mora  Tablet Air  Tecnologia         8
# 1045  2024-11-09   Norte  Ana Torres  Tablet Air  Tecnologia         8
# 1083  2024-11-27     Sur  Sofia Leon  Tablet Air  Tecnologia         8
# 1053  2024-11-13  Centro  Ana Torres  Tablet Air  Tecnologia         8
# 1162  2024-12-19   Oeste  Marta Ruiz  Tablet Air  Tecnologia         8
#
#       precio_unitario  descuento  importe
# 340            1200.0       0.15  16800.0
# ...

# %%
# Repite la consulta 4 usando query() y comprueba que da lo mismo
# Ventas de las regiones Norte o Sur d"el producto "Laptop Pro"
# ventas.query("region in ["Norte", "Sur"]" and producto == "Laptop Pro")
# Out:
#   Cell In[37], line 3
#     ventas.query("region in ["Norte", "Sur"]" and producto == "Laptop Pro")
#                  ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
