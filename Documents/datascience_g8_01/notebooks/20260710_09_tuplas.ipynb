# %%
lista = [1,3,5,7]
lista[0] = 9
print(lista)
# Out:
# [9, 3, 5, 7]

# %%
tupla = (1,3,5,7,5,5)
#tupla[0] = 9

# %%
tupla.count(5)
# Out:
# 3

# %%
tupla.index(5)
# Out:
# 2

# %%
tupla = ("maria", 1, 2, 0.5555, True, False)
print(tupla)
# Out:
# ('maria', 1, 2, 0.5555, True, False)

# %%
tupla = (1,3,5,7,5,5)
lista = list(tupla)

lista[0] = 9

tupla_nueva = tuple(lista)

print(tupla_nueva)
# Out:
# (9, 3, 5, 7, 5, 5)
