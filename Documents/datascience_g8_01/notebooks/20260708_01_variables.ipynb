# %% [markdown]
# ## Tipos de datos
#
# - Texto o cadena o string -> str
# - Numerico o numero enter o integer -> int
# - numerivo o numero decimal o Float -> float
# - Booleano o boolean -> True o False

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
nombre = "Victor"
apellido = "Lopez"

print(nombre, apellido)
print(f"Mi nombre es: {nombre} {apellido}")

print(type(nombre))
# Out:
# Victor Lopez
# Mi nombre es: Victor Lopez
# <class 'str'>

# %%
edad = 30
print(type(edad))

altura = 1.68
print(type(altura))

es_hombre = True
es_mujer = False

print(type(es_hombre))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
print(
    f"Mi nombre es: {nombre}, tengo {edad} años, y mido {altura}")
# Out:
# Mi nombre es: Victor, tengo 30 años, y mido 1.68
